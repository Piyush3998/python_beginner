# %% [markdown]
# # Python Array

# %%
# Should contain same type of data type!
from IPython.display import Image
Image('array.png')

# %%
Image('type_code.png')

# %%
import array as arr
arr1=arr.array('i',[3,9,19,98])  # here i means thte type code of data
print(arr1)
arr2=arr.array('f',[1.2,2.3,3.4,5.5])
print(arr2)
arr2[3]  # changeable...
# Out:
# array('i', [3, 9, 19, 98])
# array('f', [1.2000000476837158, 2.299999952316284, 3.4000000953674316, 5.5])
# 5.5

# %%
arr1[2:4]
# Out:
# array('i', [19, 98])

# %%
arr1.append(1998) # ran two times
arr1
# Out:
# array('i', [3, 9, 19, 98, 1998, 1998])

# %%
del arr1[-1]

# %%
arr1
len (arr1)
arr1.reverse()
arr1
# Out:
# array('i', [98, 19, 9, 3])

# %%
arr1.count(98)
# Out:
# 1

# %%
arr1.index(98)
# Out:
# 0

# %%
arr2.pop(3)
# Out:
# 5.5

# %%
arr2 # the data of thirs index has been popped!
# Out:
# array('f', [1.2000000476837158, 2.299999952316284, 3.4000000953674316])

# %%
arr2
arr2.remove(1.2000000476837158)
arr2
# Out:
# array('f', [3.4000000953674316])

# %%
import array

r = array.array('i', [])

items = int(input("Enter the number of items: "))
for i in range(items):
    val = int(input("Enter a value: "))
    r.append(val)

print("Array:", r)
