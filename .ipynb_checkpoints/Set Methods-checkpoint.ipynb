# %%
from IPython.display import Image  # display metohod
Image('pysets.png')

# %%
set1={3,9,19,98}
set2={1,2,3,4}

# %%
set3=frozenset(set2)
set3
# Out:
# frozenset({1, 2, 3, 4})

# %%
set1.add('DOB')
set1
# Out:
# {19, 3, 9, 98, 'DOB'}

# %%
set2=set1

# %%
set2.remove('DOB') #removes element from set

# %%
set2
# Out:
# {3, 9, 19, 98}

# %%
set4={'I','am','Piyush'}

# %%
set5=set4.copy() #copy function

# %%
set5.remove('am')

# %%
set5
# Out:
# {'I', 'Piyush'}

# %%
set4
# Out:
# {'I', 'Piyush', 'am'}

# %%
s1={3,9,19,98}   # difference method
s2={1,2,3,4}
s3={0}
s1.difference(s2), s2.difference(s1)
# Out:
# ({9, 19, 98}, {1, 2, 4})

# %%
s2.difference(s1)
# Out:
# {1, 2, 4}

# %%
s2
# Out:
# {1, 2, 3, 4}
