# %%
from IPython.display import Image
Image('all_types.png')

# %%
dic= {
        'name':'Piyush',
        'varsity':'Daffodil',
        'address':'Tangail'
}
dic.keys(), dic.values(), type(dic)
# Out:
# (dict_keys(['name', 'varsity', 'address']),
#  dict_values(['Piyush', 'Daffodil', 'Tangail']),
#  dict)

# %%
dic2=dic.copy()
dic2
# Out:
# {'name': 'Piyush', 'varsity': 'Daffodil', 'address': 'Tangail'}

# %%
dic2['varsity'] = 'ANU'
dic2
# Out:
# {'name': 'Piyush', 'varsity': 'ANU', 'address': 'Tangail'}

# %%
dic['dept']='CSE'
dic
# Out:
# {'name': 'Piyush', 'varsity': 'Daffodil', 'address': 'Tangail', 'dept': 'CSE'}

# %%
dic2.popitem()
dic2
# Out:
# {'name': 'Piyush', 'varsity': 'ANU'}

# %%
dic.pop('varsity')
dic
# Out:
# {'name': 'Piyush', 'address': 'Tangail', 'dept': 'CSE'}

# %%
del dic ['name']  # delete function
dic
# Out:
# {'address': 'Tangail', 'dept': 'CSE'}

# %%
for x in dic:
    print(dic[x])
# Out:
# Tangail
# CSE

# %%
for x in dic:
    print(x)
# Out:
# address
# dept

# %%
d1=list(dic.keys())
d2=list(dic.values())

d1 d2
# Out:
# ['Tangail', 'CSE']

# %%
# dictonary fro user input::::

n=int(input('Enter: '))
D={}

for i in range(n):
    key=input()
    values=input()
    D[key]=values
print(D)
# Out:
# {'Name': 'Piyush', 'Movie': 'Guardian of the galaxy vol. 3', 'Anime': 'Jujutsu Kaisen'}
